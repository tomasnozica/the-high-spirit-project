# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Main Goal: Analyze motivational quotes and generate new ones.
# Section Goal: Get motivational quotes, process and saving them.
#
# We will start with the following steps:
#
# 1. Getting the data
# 2. Cleaning the data
# 3. Organizing the data
#
# The input: 300 Quotes from https://www.oberlo.com/blog/motivational-quotes
# The output: Corpus (a collection of text) and Document-term-matrix.

# %% [markdown]
# # Getting the data

# %% [markdown]
# The quotes will be obtained from the url specified before, if we navigate in the inspector we observe that each quote is between "li> </li"
# Then as we have some format issues we erase unnecesary characters.

# %%
import requests
from bs4 import BeautifulSoup
import pickle

def url_to_transcript(url):
    page = requests.get(url).text
    soup = BeautifulSoup(page, "lxml")
    text = [p.text for p in soup.find(class_="single-post-content lg:px-10").find_all('ol')]
    quotes = []
    result = []
    for item in text:
        quotes.append(item.split('\n'))
    for group in quotes:
        for quote in group:
            if quote!='':
                end = quote.find('.')
                if end>0:
                    result.append(quote[1:end])
    return result

# %% [markdown]
# With the cell bellow we create the array with all the quotes

# %%
url = 'https://www.oberlo.com/blog/motivational-quotes'

quotes = url_to_transcript(url)

# %% [markdown]
# We create a folder with all the quotes, one quote per file in it.

# %%
for i in quotes:
     with open("quotes/quote" + str(quotes.index(i)) + ".txt", "wb") as file:
         pickle.dump(i, file)

# %%
# Load pickled files
data = []
for i in quotes:
    with open("quotes/quote" + str(quotes.index(i)) + ".txt", "rb") as file:
        data.append(pickle.load(file))

# %% [markdown]
# You can check if the file contains what you expect

# %%
for quote in data:
    print("-",quote)
# Out:
# - All our dreams can come true, if we have the courage to pursue them
# - The secret of getting ahead is getting started
# - I’ve missed more than 9,000 shots in my career
# - Don’t limit yourself
# - The best time to plant a tree was 20 years ago
# - Only the paranoid survive
# - It’s hard to beat a person who never gives up
# - I wake up every morning and think to myself, ‘how far can I push this company in the next 24 hours
# - If people are doubting how far you can go, go so far that you can’t hear them anymore
# - “We need to accept that we won’t always make the right decisions, that we’ll screw up royally sometimes – understanding that failure is not the opposite of success, it’s part of success
# - Write it
# - You’ve gotta dance like there’s nobody watching, love like you’ll never be hurt, sing like there’s nobody listening, and live like it’s heaven on earth
# - Fairy tales are more than true: not because they tell us that dragons exist, but because they tell us that dragons can be beaten
# - Everything you can imagine is real
# - When one door of happiness closes, another opens; but often we look so long at the closed door that we do not see the one which has been opened for us
# - Do one thing every day that scares you
# - It’s no use going back to yesterday, because I was a different person then
# - Smart people learn from everything and everyone, average people from their experiences, stupid people already have all the answers
# - Do what you feel in your heart to be right – for you’ll be criticized anyway
# - Happiness is not something ready made
# - Whatever you are, be a good one
# - The same boiling water that softens the potato hardens the egg
# - If we have the attitude that it’s going to be a great day it usually is
# - You can either experience the pain of discipline or the pain of regret
# - Impossible is just an opinion
# - Your passion is waiting for your courage to catch up
# - Magic is believing in yourself
# - If something is important enough, even if the odds are stacked against you, you should still do it
# - Hold the vision, trust the process
# - Don’t be afraid to give up the good to go for the great
# - People who wonder if the glass is half empty or full miss the point
# - One day or day one
# - It’s Monday… time to motivate and make dreams and goals happen
# - It was a Monday and they walked on a tightrope to the sun
# - Goodbye blue Monday
# - So
# - When life gives you Monday, dip it in glitter and sparkle all day
is impossible to live without failing at something, unless you live so cautiously that you might as well not have lived at all – in which case, you fail by default
# - Failure isn’t the end of the road
# - No matter what people tell you, words and ideas can change the world
# - Life is like riding a bicycle
# - You’re off to Great Places! Today is your day! Your mountain is waiting, so… get on your way!” – Dr
# - When thinking about life, remember this: no amount of guilt can change the past and no amount of anxiety can change the future
# - A negative mind will never give you a positive life
# - Everything is hard before it is easy
# - At the end of the day we can endure much more than we think we can
# - Whatever you do never run back to what broke you
# - Take the risk or lose the chance
# - I didn’t learn to be quiet when I had an opinion
# - Never regret a day in your life
# - Either you run the day, or the day runs you
# - Only I can change my life
# - Life is 10% what happens to you and 90% how you react to it
# - Act as if what you do makes a difference
# - hen the pain of an obstacle is too great, challenge yourself to be stronger
# - Even if you’re on the right track, you’ll get run over if you just sit there
# - Very little is needed to make a happy life; it is all within yourself, in your way of thinking
# - Life is either a daring adventure or nothing at all
# - The woman who follows the crowd will usually go no further than the crowd
# - Life’s like a movie, write your own ending
# - A reader lives a thousand lives before he dies
# - I find television very educating
# - Never stop learning because life never stops teaching
# - If you’re the smartest person in the room, you’re in the wrong room
# - The capacity to learn is a gift; the ability to learn is a skill; the willingness to learn is a choice
# - The man who does not read has no advantage over the man who cannot read
# - To learn a language is to have one more window from which to look at the world
# - I’m still learning
# - Live as if you were to die tomorrow
# - Education is the most powerful weapon you can use to change the world
# - Strength does not come from winning
# - If it doesn’t challenge you, it doesn’t change you
# - A dream doesn’t become reality through magic; it takes sweat, determination and hard work
# - Every night her thoughts weighed heavily on her soul but every morning she would get up and fight another day, every night she survived
# - Still, I rise
# - The best thing you can do is MASTER the chaos in you
# - Flowers grow back even after the harshest winters
# - Life has many ways of testing a person’s will, either by having nothing happen at all or by having everything happen all at once
# - Be strong enough to let go and wise enough to wait for what you deserve
# - It’s okay to be a glowstick: Sometimes we have to break before we shine
# - What is coming is better than what is gone
# - Attitude is a choice
# - Dwell on the beauty of life
# - Do something today that your future self will thank you for
# - The greatest weapon against stress is the ability to choose one thought over another
# - It takes nothing to join the crowd
# - Your mind is powerful
# - Your only limit is your mind
# - Stop being afraid of what can go wrong and start being positive about what can go right
# - The difference between who you are and who you want to be is what you do
# - You were born to win, but to be a winner, you must plan to win, prepare to win, and expect to win
# - One thing’s for sure, if you don’t play, you don’t win
# - Winning means you’re willing to go longer, work harder, and give more than anyone else
# - Talent wins games, but teamwork wins championships
# - When I win and when I lose, I take ownership of it, because I really am in charge of what I do
# - A champion is afraid of losing
# - Competing at the highest level is not about winning
# - A winner is a dreamer who never gives up
# - The secret of your future is hidden in your daily routine
# - Losers quit when they fail
# - It is never too late to be what you might have been
# - Words can inspire, thoughts can provoke, but only action truly brings you closer to your dreams
# - Don’t stop when you are tired
# - Don’t tell people about your dreams
# - Revenge is a powerful motivator
# - Motivation may be what starts you off, but it’s habit that keeps you going back for more
# - I will not erase all my hard work this week because it’s the weekend
# - It might not be easy but it’ll be worth it
# - Make your fear of losing your greatest motivator
# - You will never always be motivated, so you must learn to be disciplined
# - I’m not a product of my circumstances

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# Now its time to put the text in lowercase and erase punctuation

# %%
import re
import string

def clean_text(text):
    text = text.lower()
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('[‘’“”…]', '', text)
    return text

# %%
cleanQuote = []
for quote in data:
    cleanQuote.append(clean_text(quote))
print(cleanQuote)
# Out:
# ['all our dreams can come true if we have the courage to pursue them', 'the secret of getting ahead is getting started', 'ive missed more than 9000 shots in my career', 'dont limit yourself', 'the best time to plant a tree was 20 years ago', 'only the paranoid survive', 'its hard to beat a person who never gives up', 'i wake up every morning and think to myself how far can i push this company in the next 24 hours', 'if people are doubting how far you can go go so far that you cant hear them anymore', 'we need to accept that we wont always make the right decisions that well screw up royally sometimes – understanding that failure is not the opposite of success its part of success', 'write it', 'youve gotta dance like theres nobody watching love like youll never be hurt sing like theres nobody listening and live like its heaven on earth', 'fairy tales are more than true not because they tell us that dragons exist but because they tell us that dragons can be beaten', 'everything you can imagine is real', 'when one door of happiness closes another opens but often we look so long at the closed door that we do not see the one which has been opened for us', 'do one thing every day that scares you', 'its no use going back to yesterday because i was a different person then', 'smart people learn from everything and everyone average people from their experiences stupid people already have all the answers', 'do what you feel in your heart to be right – for youll be criticized anyway', 'happiness is not something ready made', 'whatever you are be a good one', 'the same boiling water that softens the potato hardens the egg', 'if we have the attitude that its going to be a great day it usually is', 'you can either experience the pain of discipline or the pain of regret', 'impossible is just an opinion', 'your passion is waiting for your courage to catch up', 'magic is believing in yourself', 'if something is important enough even if the odds are stacked against you you should still do it', 'hold the vision trust the process', 'dont be afraid to give up the good to go for the great', 'people who wonder if the glass is half empty or full miss the point', 'one day or day one', 'its monday time to motivate and make dreams and goals happen', 'it was a monday and they walked on a tightrope to the sun', 'goodbye blue monday', 'so', 'when life gives you monday dip it in glitter and sparkle all day', 'no one is to blame for your future situation but yourself', 'things may come to those who wait but only the things left by those who hustle', 'everything comes to him who hustles while he waits', 'every sucessful person in the world is a hustler one way or another', 'invest in your dreams', 'hustlers dont sleep they nap', 'greatness only comes before hustle in the dictionary', 'without hustle talent will only carry you so far', 'work like there is someone working twenty four hours a day to take it away from you', 'hustle in silence and let your success make the noise', 'we are what we repeatedly do', 'if youre offered a seat on a rocket ship dont ask what seat just get on', 'i always did something i was a little not ready to do', 'if you hear a voice within you say you cannot paint then by all means paint and that voice will be silenced', 'how wonderful it is that nobody need wait a single moment before starting to improve the world', 'some people want it to happen some wish it would happen others make it happen', 'if you hire people just because they can do a job theyll work for your money', 'very often a change of self is needed more than a change of scene', 'leaders can let you fail and yet not let you be a failure', 'its not the load that breaks you down its the way you carry it', 'the hard days are what make you stronger', 'if you believe itll work out youll see opportunities', 'keep your eyes on the stars and your feet on the ground', 'you can waste your lives drawing lines', 'youve got to get up every morning with determination if youre going to g ...

# %% [markdown]
# # Organizing the Data

# %% [markdown]
# Now that we our corpus we save it for further purposes

# %%
filename = "corpus.pkl"
outfile = open(filename,'wb')
pickle.dump(cleanQuote,outfile)
outfile.close()

# %% [markdown]
# Finally, we will make an array counting each word also for further purposes

# %%
import nltk
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

raw = ' '.join(cleanQuote)
tokenizer = RegexpTokenizer(r'[A-Za-z]{2,}')
words = tokenizer.tokenize(raw)

stop_words = set(stopwords.words('english'))
stop_words.add('dont')
stop_words.add('youre')
words = [word for word in words if word not in stop_words]

counter = Counter()
counter.update(words)

# %%
filename = "data_clean.pkl"
outfile = open(filename,'wb')
pickle.dump(words,outfile)
outfile.close()

# %%
filename = "dtm.pkl"
outfile = open(filename,'wb')
pickle.dump(counter,outfile)
outfile.close()
